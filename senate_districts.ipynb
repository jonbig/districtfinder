# %%
# import relevant packages
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
from shapely.geometry import Point

# %%
#import the shapefile by drag and dropping the entire folder into JN and copying the path. Need all the files in the folder.
#inspect the first 5 rows to make sure it worked at the geometry column is there
s_districts = gpd.read_file("Desktop/2022_colorado_senate")
s_districts.head()
# Out:
#   STATEFP20 SLDUST20 GEOID20                NAMELSAD20 LSAD20 LSY20 MTFCC20  \
# 0        08      027   08027  State Senate District 27     LU  2018   G5210
# 1        08      024   08024  State Senate District 24     LU  2018   G5210
# 2        08      016   08016  State Senate District 16     LU  2018   G5210
# 3        08      019   08019  State Senate District 19     LU  2018   G5210
# 4        08      004   08004   State Senate District 4     LU  2018   G5210
#
#   FUNCSTAT20     ALAND20  AWATER20   INTPTLAT20    INTPTLON20  \
# 0          N   106321904    387462  +39.5912922  -104.8524227
# 1          N   117038042   1968747  +39.9305088  -104.9852950
# 2          N  2147606347  14731730  +39.6362458  -105.3446743
# 3          N   110684010   6064748  +39.8478125  -105.1055719
# 4          N  1850790064   2713865  +39.3035875  -104.9447571
#
#                                             geometry
# 0  POLYGON ((-104.98835 39.58787, -104.98834 39.5...
# ...

# %%
def senate_function(long, lat):  
    coordinates_2 = Point(long, lat) 
    for row in s_districts["geometry"]:
        if coordinates_2.within(row) == True:
            print(s_districts['NAMELSAD20'].values[s_districts.geometry==row])

# %%
val = senate_function(-105.0011828, 39.7511817)
# Out:
# ['State Senate District 34']

# %%
def senate_function_1(long, lat):  
    coordinates_2 = Point(long, lat) 
    for row in s_districts["geometry"]:
        if coordinates_2.within(row) == True: 
            print([s_districts.geometry==row])

# %%
senate_function_1(-105.0011828, 39.7511817)
# Out:
# [0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24     True
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# Name: geometry, dtype: bool]
